# %%
import pandas as pd
from selenium import webdriver
import time
from bs4 import BeautifulSoup

# %%
driver = webdriver.Chrome(executable_path=r"C:\Users\khuboo\OneDrive\Desktop\chromedriver-win64\chromedriver.exe")
# Out:
# C:\Users\khuboo\AppData\Local\Temp\ipykernel_8880\2912017659.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=r"C:\Users\khuboo\OneDrive\Desktop\chromedriver-win64\chromedriver.exe")

# %%
# from selenium import webdriver

# # Specify the full path to chromedriver.exe
# chromedriver_path = r"C:\Users\khuboo\Downloads\chromedriver.exe"

# # Initialize the Chrome WebDriver with the specified path
# driver = webdriver.Chrome(executable_path=chromedriver_path)
# # driver = webdriver.Chrome(executable_path=r"C:\Users\khuboo\Downloads\chromedriver.exe")

# %%
driver.get('https://www.linkedin.com/')

# %%
soup = BeautifulSoup(driver.page_source, 'lxml')
soup
# Out:
# <html lang="en"><head>
# <meta content="d_homepage-guest-home" name="pageKey"/>
# <!-- --><!-- --> <meta content="en_US" name="locale"/>
# <meta data-app-version="2.1.1474" data-browser-id="65e523e0-39be-41dc-8e28-bd6ec6d0a417" data-call-tree-id="AAYchg2CUb98SPcY/NrC4A==" data-disable-jsbeacon-pagekey-suffix="false" data-enable-page-view-heartbeat-tracking="" data-jet-tags="guest-homepage" data-member-id="0" data-multiproduct-name="homepage-guest-frontend" data-page-instance="urn:li:page:d_homepage-guest-home;pSF/jaUpS9yooJXBVIMY0Q==" data-service-name="homepage-guest-frontend" id="config"/>
# <link href="https://www.linkedin.com/" rel="canonical"/>
# <link href="https://de.linkedin.com/" hreflang="de" rel="alternate"/>
# <link href="https://ie.linkedin.com/" hreflang="en-IE" rel="alternate"/>
# <link href="https://www.linkedin.com/" hreflang="en-US" rel="alternate"/>
# <link href="https://pt.linkedin.com/" hreflang="pt" rel="alternate"/>
# ...

# %%
for i in soup:
    soups = soup.find_all("li", class_ = 'reusable-search__result-container')
    print(i)
# Out:
# <html lang="en"><head>
# <meta content="d_homepage-guest-home" name="pageKey"/>
# <!-- --><!-- --> <meta content="en_US" name="locale"/>
# <meta data-app-version="2.1.1474" data-browser-id="65e523e0-39be-41dc-8e28-bd6ec6d0a417" data-call-tree-id="AAYchg2CUb98SPcY/NrC4A==" data-disable-jsbeacon-pagekey-suffix="false" data-enable-page-view-heartbeat-tracking="" data-jet-tags="guest-homepage" data-member-id="0" data-multiproduct-name="homepage-guest-frontend" data-page-instance="urn:li:page:d_homepage-guest-home;pSF/jaUpS9yooJXBVIMY0Q==" data-service-name="homepage-guest-frontend" id="config"/>
# <link href="https://www.linkedin.com/" rel="canonical"/>
# <link href="https://de.linkedin.com/" hreflang="de" rel="alternate"/>
# <link href="https://ie.linkedin.com/" hreflang="en-IE" rel="alternate"/>
# <link href="https://www.linkedin.com/" hreflang="en-US" rel="alternate"/>
# <link href="https://pt.linkedin.com/" hreflang="pt" rel="alternate"/>
# ...

# %%
try:
    boxe = soup.find_all("li", class_="reusable-search__result-container")
    if boxe:
        print(boxe)
    else:
        print("No matching elements found.")
except Exception as e:
    print("An error occurred:", e)
# Out:
# No matching elements found.

# %%
for i in boxe:
    link = i.find('a').get('href')
    print(i)

# %%
df = pd.DataFrame({'Link':[''], 'Name':[''], 'Title':[''], 'Location':['']})

while True:      
    soup = BeautifulSoup(driver.page_source, 'lxml')
    boxes = soup.find_all('li', class_ = 'reusable-search__result-container')

    for i in boxes:
        try:
            link = i.find('a').get('href')
            name = i.find('span', {'dir': 'ltr'}).find('span', {'aria-hidden': 'true'}).text
            title = i.find('div', class_ = 'entity-result__primary-subtitle t-14 t-black t-normal').text
            location = i.find('div', class_ = 'entity-result__secondary-subtitle t-14 t-normal').text
            df = df.append({'Link':link, 'Name':name, 'Title':title, 'Location':location}, ignore_index = True)
        except:
            pass
    driver.execute_script('window.scrollTo(0,document.body.scrollHeight)')
    time.sleep(1)
    driver.find_element_by_xpath('/html/body/div[4]/div[3]/div[2]/div/div[1]/main/div/div/div/div[2]/div/button[2]').click()
    time.sleep(3)

df.drop_duplicates(inplace = True)
# Out:
# C:\Users\khuboo\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:483: UserWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [11], in <cell line: 4>()
#      16     driver.execute_script('window.scrollTo(0,document.body.scrollHeight)')
#      17     time.sleep(1)
# ---> 18     driver.find_element_by_xpath('/html/body/div[4]/div[3]/div[2]/div/div[1]/main/div/div/div/div[2]/div/button[2]').click()
#      19     time.sleep(3)
#      21 df.drop_duplicates(inplace = True)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:484, in WebDriver.find_element_by_xpath(self, xpath)
#     466 """
#     467 Finds an element by xpath.
#     468
#    (...)
# ...
